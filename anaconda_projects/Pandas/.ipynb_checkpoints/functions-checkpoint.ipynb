# %%
import numpy as np
import pandas as pd

# %%
company = pd.read_csv('Fortune500.csv', encoding='latin1')
company.head(2)
# Out:
#    Rank        Company Name Number of Employees  Previous Rank   Revenues  \
# 0     1             Walmart           23,00,000            1.0  $4,85,873
# 1     2  Berkshire Hathaway            3,67,700            4.0  $2,23,604
#
#   Revenue Change    Profits Profit Change     Assets Market Value
# 0           0.8%  $13,643.0         -7.2%  $1,98,825    $2,18,619
# 1           6.1%  $24,074.0          0.0%  $6,20,854    $4,11,035

# %%
revenues = company.groupby('Revenues')

# %%
revenues

# %%
len(company)
# Out:
# 500

# %%
len(revenues)
# Out:
# 495

# %%
revenues.size().sort_values(ascending=False)
# Out:
# Revenues
# $9,061       3
# $12,394      2
# $6,632       2
# $7,651       2
# $1,25,980    1
#             ..
# $10,964      1
# $11,047      1
# $11,069      1
# $11,107      1
# $1,15,337    1
# Length: 495, dtype: int64

# %%
revenues.first()
# Out:
#            Rank             Company Name Number of Employees  Previous Rank  \
# Revenues
# $1,00,288    22  Express Scripts Holding              25,600           22.0
# $1,05,486    21        J.P. Morgan Chase            2,43,355           23.0
# $1,07,162    20               Fannie Mae               7,000           16.0
# $1,07,567    19                  Chevron              55,200           14.0
# $1,15,337    18                   Kroger            4,43,000           17.0
# ...         ...                      ...                 ...            ...
# $90,272      27                 Alphabet              72,053           36.0
# $93,662      26    Bank of America Corp.            2,08,024           26.0
# $94,176      25              Wells Fargo            2,69,100           27.0
# $94,571      24                   Boeing            1,50,540           24.0
# $94,595      23               Home Depot            4,06,000           28.0
#
# ...

# %%
 revenues.last()
# Out:
#            Rank             Company Name Number of Employees  Previous Rank  \
# Revenues
# $1,00,288    22  Express Scripts Holding              25,600           22.0
# $1,05,486    21        J.P. Morgan Chase            2,43,355           23.0
# $1,07,162    20               Fannie Mae               7,000           16.0
# $1,07,567    19                  Chevron              55,200           14.0
# $1,15,337    18                   Kroger            4,43,000           17.0
# ...         ...                      ...                 ...            ...
# $90,272      27                 Alphabet              72,053           36.0
# $93,662      26    Bank of America Corp.            2,08,024           26.0
# $94,176      25              Wells Fargo            2,69,100           27.0
# $94,571      24                   Boeing            1,50,540           24.0
# $94,595      23               Home Depot            4,06,000           28.0
#
# ...

# %%
revenues.groups
# Out:
# {'$1,00,288': [21], '$1,05,486': [20], '$1,07,162': [19], '$1,07,567': [18], '$1,15,337': [17], '$1,17,351': [16], '$1,18,719': [15], '$1,21,546': [14], '$1,25,980': [13], '$1,26,661': [12], '$1,35,987': [11], '$1,46,850': [10], '$1,51,800': [9], '$1,63,786': [8], '$1,66,380': [7], '$1,77,526': [6], '$1,84,840': [5], '$1,92,487': [4], '$10,074': [282], '$10,137': [281], '$10,163': [280], '$10,183': [279], '$10,261': [278], '$10,398': [277], '$10,497': [276], '$10,508': [275], '$10,534': [274], '$10,536': [273], '$10,597': [272], '$10,630': [271], '$10,635': [270], '$10,636': [269], '$10,647': [268], '$10,743': [267], '$10,776': [266], '$10,782': [265], '$10,825': [264], '$10,842': [263], '$10,846': [262], '$10,875': [261], '$10,888': [260], '$10,950': [259], '$10,964': [258], '$11,047': [257], '$11,069': [256], '$11,107': [255], '$11,155': [254], '$11,229': [253], '$11,262': [252], '$11,325': [251], '$11,361': [250], '$11,407': [249], '$11,410': [248], '$11,449': [247], '$11,507': [2
# ...

# %%
company.iloc[21,:]
# Out:
# Rank                                        22
# Company Name           Express Scripts Holding
# Number of Employees                     25,600
# Previous Rank                             22.0
# Revenues                             $1,00,288
# Revenue Change                           -1.4%
# Profits                               $3,404.4
# Profit Change                            37.5%
# Assets                                 $51,745
# Market Value                           $39,567
# Name: 21, dtype: object

# %%
# agar saare group meh se koi ek type ka chahiye toh get_group() use hota hai
revenues.get_group('1,00,288')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 2
#       1 # agar saare group meh se koi ek type ka chahiye toh get_group() use hota hai
# ----> 2 revenues.get_group('1,00,288')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1114, in BaseGroupBy.get_group(self, name, obj)
#    1112 inds = self._get_index(name)
#    1113 if not len(inds):
# -> 1114     raise KeyError(name)
#    1116 if obj is None:
#    1117     indexer = inds if self.axis == 0 else (slice(None), inds)
#
# KeyError: '1,00,288'

# %%
revenues.sum()
# Out:
#            Rank             Company Name Number of Employees  Previous Rank  \
# Revenues
# $1,00,288    22  Express Scripts Holding              25,600           22.0
# $1,05,486    21        J.P. Morgan Chase            2,43,355           23.0
# $1,07,162    20               Fannie Mae               7,000           16.0
# $1,07,567    19                  Chevron              55,200           14.0
# $1,15,337    18                   Kroger            4,43,000           17.0
# ...         ...                      ...                 ...            ...
# $90,272      27                 Alphabet              72,053           36.0
# $93,662      26    Bank of America Corp.            2,08,024           26.0
# $94,176      25              Wells Fargo            2,69,100           27.0
# $94,571      24                   Boeing            1,50,540           24.0
# $94,595      23               Home Depot            4,06,000           28.0
#
# ...

# %%
revenues['Profits'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
# ...
