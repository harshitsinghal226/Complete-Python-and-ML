# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Pie Chart

# %%
areas=['Marketing', 'Sales', 'Development', 'HR', 'Customer Support']
budget=[2.5, 4, 10, 1, 6]

# %%
plt.pie(budget, labels=areas, autopct="%0.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1f535c85d10>,
#   <matplotlib.patches.Wedge at 0x1f535c860d0>,
#   <matplotlib.patches.Wedge at 0x1f535c86490>,
#   <matplotlib.patches.Wedge at 0x1f535c86850>,
#   <matplotlib.patches.Wedge at 0x1f535c86c10>],
#  [Text(1.0391359932945505, 0.3608273651481383, 'Marketing'),
#   Text(0.39534842462775427, 1.026498720478673, 'Sales'),
#   Text(-1.097543578735165, 0.07347171413004353, 'Development'),
#   Text(-0.18296193275584066, -1.0846773396555527, 'HR'),
#   Text(0.7647118070885887, -0.7907059201114567, 'Customer Support')],
#  [Text(0.5668014508879367, 0.19681492644443907, '10.6%'),
#   Text(0.2156445952515023, 0.5599083929883671, '17.0%'),
#   Text(-0.5986601338555445, 0.04007548043456919, '42.6%'),
#   Text(-0.09979741786682217, -0.591642185266665, '4.3%'),
#   Text(0.4171155311392301, -0.4312941382426127, '25.5%')])

# %%
plt.show()

# %%
x=[23,45,12,49,97,32,11,44]
y=[45,34,67,87,55,22,89,90]

plt.scatter(x,y)
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Age Vs Salary Graph')
# Out:
# Text(0.5, 1.0, 'Age Vs Salary Graph')

# %%
plt.show()

# %%
product_id = [1,2,3,4,5,6,7,8]
online_price = [233,456,770,120,222,444,200,300]
offline_price=[400,300,100,333,444,565,565,899]
chor_bazar=[100,200,300,400,150,250,450,500]

# %%
# D for diamond
plt.plot(product_id, online_price, color='red', marker='D', markersize=10, label='Online Prices')
plt.plot(product_id, offline_price, color='yellow', markersize=10, label='Offline Prices')
plt.plot(product_id, chor_bazar, color='green', marker='+', markersize=10, label='Chori wale prices')
plt.xlabel("Product")
plt.ylabel("Prices")
plt.title("Product Price Comparsion")
# Out:
# Text(0.5, 1.0, 'Product Price Comparsion')

# %%
plt.legend()
plt.show()

# %%
year=[2012,2013,2014,2015,2016,2017,2018]

price=[65000, 69000, 75000, 55000, 52000, 64000, 81000]

plt.bar(year, price, color='cyan')
plt.xlabel('Year')
plt.ylabel("Price(in INR)")
plt.title("Year by Year Price Comp.")
# Out:
# Text(0.5, 1.0, 'Year by Year Price Comp.')

# %%
plt.show()
